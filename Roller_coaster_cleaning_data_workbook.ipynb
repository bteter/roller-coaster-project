# %% [markdown]
# Cleaning Roller Coaster Dataset.
#
# Objectives:
# - Clean any missing, irregular, unnecessary, or inconsistent data.
# - Detect missing data (null values) and decide how to handle it.
# - Make all units of measurement (height, speed, etc) universal. Just using MPH and ft.
# - Drop unnecessary columns
# - Detect inconsistent data and how to handle it.

# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv("/Users/benjaminteter/Desktop/Roller_Coaster_Project/coaster_db.csv")

# %%
pd.reset_option('^display.', silent=True)

# %%
df.head(25)
# Out:
#                               coaster_name              Length  \
# 0                       Switchback Railway      600 ft (180 m)
# 1                        Flip Flap Railway                 NaN
# 2   Switchback Railway (Euclid Beach Park)                 NaN
# 3             Loop the Loop (Coney Island)                 NaN
# 4             Loop the Loop (Young's Pier)                 NaN
# 5                           Cannon Coaster                 NaN
# 6                            Leap-The-Dips    1,452 ft (443 m)
# 7         Figure Eight (Euclid Beach Park)                 NaN
# 8                             Drop the Dip                 NaN
# 9       Scenic Railway (Euclid Beach Park)                 NaN
# 10          Loop the Loop (Olentangy Park)                 NaN
# 11                               Aero Dips                 NaN
# 12             Backety-Back Scenic Railway                 NaN
# 13             Racer (1910 roller coaster)  4,500 ft (1,400 m)
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
#remove any non operational coasters
# cleaned table now called df_operational. Includes only "Operating" roller coasters

df_operating = df[df['Status'] == 'Operating']
df_operating
# Out:
#                       coaster_name                Length  \
# 6                    Leap-The-Dips      1,452 ft (443 m)
# 13     Racer (1910 roller coaster)    4,500 ft (1,400 m)
# 15        The Great Scenic Railway      967 m (3,173 ft)
# 22         Jack Rabbit (Kennywood)      2,132 ft (650 m)
# 23         Jack Rabbit (Seabreeze)      2,130 ft (650 m)
# ...                            ...                   ...
# 1066          Monster (Gröna Lund)  2,296.6 ft (700.0 m)
# 1068  Storm Chaser (Paultons Park)                   NaN
# 1069  Stunt Pilot (roller coaster)      1,800 ft (550 m)
# 1070         The Ride to Happiness  3,018.4 ft (920.0 m)
# 1071                 VelociCoaster    4,700 ft (1,400 m)
#
#                      Speed                          Location     Status  \
# 6         10 mph (16 km/h)                     Lakemont Park  Operating
# 13        40 mph (64 km/h)                         Kennywood  Operating
# ...

# %%
df_cleaned = df_operating
df_cleaned
# Out:
#                       coaster_name                Length  \
# 6                    Leap-The-Dips      1,452 ft (443 m)
# 13     Racer (1910 roller coaster)    4,500 ft (1,400 m)
# 15        The Great Scenic Railway      967 m (3,173 ft)
# 22         Jack Rabbit (Kennywood)      2,132 ft (650 m)
# 23         Jack Rabbit (Seabreeze)      2,130 ft (650 m)
# ...                            ...                   ...
# 1066          Monster (Gröna Lund)  2,296.6 ft (700.0 m)
# 1068  Storm Chaser (Paultons Park)                   NaN
# 1069  Stunt Pilot (roller coaster)      1,800 ft (550 m)
# 1070         The Ride to Happiness  3,018.4 ft (920.0 m)
# 1071                 VelociCoaster    4,700 ft (1,400 m)
#
#                      Speed                          Location     Status  \
# 6         10 mph (16 km/h)                     Lakemont Park  Operating
# 13        40 mph (64 km/h)                         Kennywood  Operating
# ...

# %%
#drop un needed columns. This data set is very large and for the focus project I do not need everything here. 
## Review of all the columns

df.columns.tolist()
# Out:
# ['coaster_name',
#  'Length',
#  'Speed',
#  'Location',
#  'Status',
#  'Opening date',
#  'Type',
#  'Manufacturer',
#  'Height restriction',
#  'Model',
#  'Height',
#  'Inversions',
#  'Lift/launch system',
#  'Cost',
#  'Trains',
#  'Park section',
#  'Duration',
#  'Capacity',
#  'G-force',
#  'Designer',
#  'Max vertical angle',
#  'Drop',
#  'Soft opening date',
#  'Fast Lane available',
#  'Replaced',
#  'Track layout',
#  'Fastrack available',
#  'Soft opening date.1',
#  'Closing date',
#  'Opened',
#  'Replaced by',
#  'Website',
#  'Flash Pass Available',
#  'Must transfer from wheelchair',
#  'Theme',
#  'Single rider line available',
#  'Restraint Style',
#  'Flash Pass available',
#  'Acceleration',
#  'Restraints',
#  'Name',
#  'year_introduced',
#  'latitude',
#  'longitude',
#  'Type_Main',
#  'opening_date_clean',
#  'speed1',
#  'speed2',
#  'speed1_value',
#  'speed1_unit',
#  'speed_mph',
#  'height_value',
#  'height_unit',
#  'height_ft',
# ...

# %%
#list of what columns I want to keep

# 'coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date','Type', 'Manufacturer', 'Model', 'Height',
#'Cost' 'Duration', 'Capacity', 'G-force', 'Designer','Theme','Acceleration', 'Restraints', 'Name',
#'latitude', 'longitude','opening_date_clean','speed_mph', 'height_ft', 'Inversions_clean', 'Gforce_clean'

# %%
cleaned_columns = df_cleaned.drop(columns=[
#'coaster_name',
#'Length',
#'Speed',
'Location',
#'Status',
 'Opening date',
 'Type',
 #'Manufacturer',
 'Height restriction',
 #'Model',
 #'Height',
 'Inversions',
 #'Lift/launch system',
 'Cost',
 'Trains',
 'Park section',
 'Duration',
 'Capacity',
 #'G-force',
 #'Designer',
 'Max vertical angle',
 'Drop',
 'Soft opening date',
 'Fast Lane available',
 'Replaced',
 #'Track layout',
 'Fastrack available',
 'Soft opening date.1',
 'Closing date',
 'Opened',
 'Replaced by',
 'Website',
 'Flash Pass Available',
 'Must transfer from wheelchair',
 'Theme',
 'Single rider line available',
 'Restraint Style',
 'Flash Pass available',
 'Acceleration',
 'Restraints',
 'Name',
 'year_introduced',
 'latitude',
 'longitude',
 #'Type_Main',
 #'opening_date_clean',
 'speed1',
 'speed2',
 'speed1_value',
 'speed1_unit',
 #'speed_mph',
 'height_value',
 'height_unit',
 #'height_ft',
 #'Inversions_clean',
 'Gforce_clean'])
cleaned_columns
# Out:
#                       coaster_name                Length  \
# 6                    Leap-The-Dips      1,452 ft (443 m)
# 13     Racer (1910 roller coaster)    4,500 ft (1,400 m)
# 15        The Great Scenic Railway      967 m (3,173 ft)
# 22         Jack Rabbit (Kennywood)      2,132 ft (650 m)
# 23         Jack Rabbit (Seabreeze)      2,130 ft (650 m)
# ...                            ...                   ...
# 1066          Monster (Gröna Lund)  2,296.6 ft (700.0 m)
# 1068  Storm Chaser (Paultons Park)                   NaN
# 1069  Stunt Pilot (roller coaster)      1,800 ft (550 m)
# 1070         The Ride to Happiness  3,018.4 ft (920.0 m)
# 1071                 VelociCoaster    4,700 ft (1,400 m)
#
#                      Speed     Status                  Manufacturer  \
# 6         10 mph (16 km/h)  Operating  Federal Construction Company
# 13        40 mph (64 km/h)  Operating                  Charlie Mach
# 15        60 km/h (37 mph)  Operating             LaMarcus Thompson
# ...

# %%
cleaned_columns.columns.tolist()
# Out:
# ['coaster_name',
#  'Length',
#  'Speed',
#  'Status',
#  'Manufacturer',
#  'Model',
#  'Height',
#  'Lift/launch system',
#  'G-force',
#  'Designer',
#  'Track layout',
#  'Type_Main',
#  'opening_date_clean',
#  'speed_mph',
#  'height_ft',
#  'Inversions_clean']

# %%
df_cleaned
# Out:
#                       coaster_name                Length  \
# 6                    Leap-The-Dips      1,452 ft (443 m)
# 13     Racer (1910 roller coaster)    4,500 ft (1,400 m)
# 15        The Great Scenic Railway      967 m (3,173 ft)
# 22         Jack Rabbit (Kennywood)      2,132 ft (650 m)
# 23         Jack Rabbit (Seabreeze)      2,130 ft (650 m)
# ...                            ...                   ...
# 1066          Monster (Gröna Lund)  2,296.6 ft (700.0 m)
# 1068  Storm Chaser (Paultons Park)                   NaN
# 1069  Stunt Pilot (roller coaster)      1,800 ft (550 m)
# 1070         The Ride to Happiness  3,018.4 ft (920.0 m)
# 1071                 VelociCoaster    4,700 ft (1,400 m)
#
#                      Speed                          Location     Status  \
# 6         10 mph (16 km/h)                     Lakemont Park  Operating
# 13        40 mph (64 km/h)                         Kennywood  Operating
# ...

# %%
#reviewing null values
df_cleaned.isna().sum()
# Out:
# coaster_name                       0
# Length                            52
# Speed                             60
# Location                           0
# Status                             0
# Opening date                      11
# Type                               0
# Manufacturer                      24
# Height restriction                97
# Model                            205
# Height                            52
# Inversions                        65
# Lift/launch system               148
# Cost                             388
# Trains                           184
# Park section                     303
# Duration                         164
# Capacity                         282
# G-force                          431
# Designer                         330
# Max vertical angle               423
# Drop                             344
# Soft opening date                592
# Fast Lane available              607
# Replaced                         554
# ...

# %%
# I am creating a new workbook to review all the null values

# %%
duplicates = [df_cleaned.duplicated(keep=False)]
print(duplicates)
#no duplicates
# Out:
# [6       False
# 13      False
# 15      False
# 22      False
# 23      False
#         ...
# 1066    False
# 1068    False
# 1069    False
# 1070    False
# 1071    False
# Length: 668, dtype: bool]

# %%
cleaned_columns.columns.tolist()
# Out:
# ['coaster_name',
#  'Length',
#  'Speed',
#  'Status',
#  'Manufacturer',
#  'Model',
#  'Height',
#  'Lift/launch system',
#  'G-force',
#  'Designer',
#  'Track layout',
#  'Type_Main',
#  'opening_date_clean',
#  'speed_mph',
#  'height_ft',
#  'Inversions_clean']

# %%
df_cleaned = cleaned_columns
df_cleaned
# Out:
#                       coaster_name                Length  \
# 6                    Leap-The-Dips      1,452 ft (443 m)
# 13     Racer (1910 roller coaster)    4,500 ft (1,400 m)
# 15        The Great Scenic Railway      967 m (3,173 ft)
# 22         Jack Rabbit (Kennywood)      2,132 ft (650 m)
# 23         Jack Rabbit (Seabreeze)      2,130 ft (650 m)
# ...                            ...                   ...
# 1066          Monster (Gröna Lund)  2,296.6 ft (700.0 m)
# 1068  Storm Chaser (Paultons Park)                   NaN
# 1069  Stunt Pilot (roller coaster)      1,800 ft (550 m)
# 1070         The Ride to Happiness  3,018.4 ft (920.0 m)
# 1071                 VelociCoaster    4,700 ft (1,400 m)
#
#                      Speed     Status                  Manufacturer  \
# 6         10 mph (16 km/h)  Operating  Federal Construction Company
# 13        40 mph (64 km/h)  Operating                  Charlie Mach
# 15        60 km/h (37 mph)  Operating             LaMarcus Thompson
# ...

# %%
#review what values are in the lift/launch column 
## results are very problematic, need to clean to just contain "lift" / "launch"
df_cleaned['Lift/launch system'].unique()
# Out:
# array([nan, 'Chain lift', 'Cable lift hill', 'Chain lift hill', 'chain',
#        'Cable (two lifts)', 'Chain', 'Chain-lift', 'Chain Lift Hill',
#        'Cable-lift', 'Chainlift', 'Three chain lift hills',
#        'Two Chain lift hills',
#        'Trains are powered, propelling themselves on uphill sections. Trains then freely roll over drops. Tires embedded in the track also move trains through certain sections.',
#        'Two chain lift hills', 'Chain Lift', 'chain lift hill',
#        'Flywheel launch', '2 Chain lift hills', 'Powered coaster',
#        'Vertical Chain lift', 'Spiral lift', 'Drive tire lift hill',
#        'Cable and Chain lift hill on both towers', 'Friction Wheels',
#        'Onboard motors', 'Powered', 'Tire lift hill',
#        'Two Drive Tire Lifts',
#        'Electric Winch Launch / Booster wheels (second lift)',
#        'Lift hill', 'Linear synchronous motor', 'Drive tire',
#        'tyre-driven lift-hill', 'Tire Propelled Launch', 'LIM launch',
# ...

# %%
# Filter to only include rows with 'lift', 'launch', or 'lsm'
df_cleaned = df_cleaned[
    df_cleaned['Lift/launch system'].str.contains('lift|launch|lsm', case=False, na=False)
]

# Simplify values to just 'lift' or 'launch'
def simplify_system(value):
    value = value.lower()
    if "launch" in value or "lsm" in value or "flywheel" in value:
        return "launch"
    elif "lift" in value or "chain" in value or "tire" in value or "cable" in value or "powered" in value or "drive" in value:
        return "lift"
    else:
        return np.nan

df_cleaned['Lift/launch system'] = df_cleaned['Lift/launch system'].apply(simplify_system)

# Reset index
df_cleaned = df_cleaned.reset_index(drop=True)
# Out:
# /var/folders/8j/lkv619ks11s7t9r0db59kfsm0000gn/T/ipykernel_33318/1826674966.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Lift/launch system'] = df_cleaned['Lift/launch system'].apply(simplify_system)

# %%
df_cleaned
# Out:
#                         coaster_name                Length  \
# 0        Racer (1910 roller coaster)    4,500 ft (1,400 m)
# 1           The Great Scenic Railway      967 m (3,173 ft)
# 2            Jack Rabbit (Kennywood)      2,132 ft (650 m)
# 3    Scenic Railway (roller coaster)      3,000 ft (910 m)
# 4            Roller Coaster (Lagoon)      762 m (2,500 ft)
# ..                               ...                   ...
# 451             Monster (Gröna Lund)  2,296.6 ft (700.0 m)
# 452     Storm Chaser (Paultons Park)                   NaN
# 453     Stunt Pilot (roller coaster)      1,800 ft (550 m)
# 454            The Ride to Happiness  3,018.4 ft (920.0 m)
# 455                    VelociCoaster    4,700 ft (1,400 m)
#
#                     Speed     Status                 Manufacturer  \
# 0        40 mph (64 km/h)  Operating                 Charlie Mach
# 1        60 km/h (37 mph)  Operating            LaMarcus Thompson
# ...

# %%
#this worked, table only shows Lift or Launch system coasters
df_cleaned['Lift/launch system'].unique()
# Out:
# array(['lift', 'launch'], dtype=object)

# %%
df_cleaned
# Out:
#                         coaster_name                Length  \
# 0        Racer (1910 roller coaster)    4,500 ft (1,400 m)
# 1           The Great Scenic Railway      967 m (3,173 ft)
# 2            Jack Rabbit (Kennywood)      2,132 ft (650 m)
# 3    Scenic Railway (roller coaster)      3,000 ft (910 m)
# 4            Roller Coaster (Lagoon)      762 m (2,500 ft)
# ..                               ...                   ...
# 451             Monster (Gröna Lund)  2,296.6 ft (700.0 m)
# 452     Storm Chaser (Paultons Park)                   NaN
# 453     Stunt Pilot (roller coaster)      1,800 ft (550 m)
# 454            The Ride to Happiness  3,018.4 ft (920.0 m)
# 455                    VelociCoaster    4,700 ft (1,400 m)
#
#                     Speed     Status                 Manufacturer  \
# 0        40 mph (64 km/h)  Operating                 Charlie Mach
# 1        60 km/h (37 mph)  Operating            LaMarcus Thompson
# ...

# %%
#I will be looking a lot a manufacturers, so i want to see rows where manufacturer is unknown 
df_cleaned[df_cleaned["Manufacturer"].isna()]
# Out:
#                                       coaster_name                  Length  \
# 3                  Scenic Railway (roller coaster)        3,000 ft (910 m)
# 4                          Roller Coaster (Lagoon)        762 m (2,500 ft)
# 6                          Pippin (roller coaster)        3,250 ft (990 m)
# 9                             Coney Island Cyclone        2,640 ft (800 m)
# 12                                   Montaña Suiza    1,312.3 ft (400.0 m)
# 13                       Dragon Coaster (Playland)      1,036 m (3,399 ft)
# 15  Roller Coaster (Great Yarmouth Pleasure Beach)  3,223.10 ft (982.40 m)
# 17               Cyclone (Lakeside Amusement Park)        2,800 ft (850 m)
# 28                         Thunderbolt (Kennywood)        3,250 ft (990 m)
#
#                Speed     Status Manufacturer           Model          Height  \
# 3   35 mph (56 km/h)  Operating          NaN  Scenic Railway    40 ft (12 m)
# ...

# %%
null_rows = df_cleaned[df_cleaned["Manufacturer"].isna()]

print("Number of null Manufacturer rows:", len(null_rows))
null_rows
# Out:
# Number of null Manufacturer rows: 9
#                                       coaster_name                  Length  \
# 3                  Scenic Railway (roller coaster)        3,000 ft (910 m)
# 4                          Roller Coaster (Lagoon)        762 m (2,500 ft)
# 6                          Pippin (roller coaster)        3,250 ft (990 m)
# 9                             Coney Island Cyclone        2,640 ft (800 m)
# 12                                   Montaña Suiza    1,312.3 ft (400.0 m)
# 13                       Dragon Coaster (Playland)      1,036 m (3,399 ft)
# 15  Roller Coaster (Great Yarmouth Pleasure Beach)  3,223.10 ft (982.40 m)
# 17               Cyclone (Lakeside Amusement Park)        2,800 ft (850 m)
# 28                         Thunderbolt (Kennywood)        3,250 ft (990 m)
#
#                Speed     Status Manufacturer           Model          Height  \
# 3   35 mph (56 km/h)  Operating          NaN  Scenic Railway    40 ft (12 m)
# ...

# %%
#There are only 9 rows. This will be dropped, they aren't enough to make a different and they seem to be only very old coasters

print("Rows before:", len(df_cleaned))
df_cleaned = df_cleaned.dropna(subset=["Manufacturer"])
print("Rows after:", len(df_cleaned))
# Out:
# Rows before: 456
# Rows after: 447

# %%
df_cleaned
# Out:
#                      coaster_name                Length                 Speed  \
# 0     Racer (1910 roller coaster)    4,500 ft (1,400 m)      40 mph (64 km/h)
# 1        The Great Scenic Railway      967 m (3,173 ft)      60 km/h (37 mph)
# 2         Jack Rabbit (Kennywood)      2,132 ft (650 m)      45 mph (72 km/h)
# 5                    Giant Dipper      2,640 ft (800 m)      55 mph (89 km/h)
# 7       Thunderhawk (Dorney Park)      2,767 ft (843 m)      45 mph (72 km/h)
# ..                            ...                   ...                   ...
# 451          Monster (Gröna Lund)  2,296.6 ft (700.0 m)  55.9 mph (90.0 km/h)
# 452  Storm Chaser (Paultons Park)                   NaN                   NaN
# 453  Stunt Pilot (roller coaster)      1,800 ft (550 m)      52 mph (84 km/h)
# 454         The Ride to Happiness  3,018.4 ft (920.0 m)  55.9 mph (90.0 km/h)
# 455                 VelociCoaster    4,700 ft (1,400 m)     70 mph (110 km/h)
#
# ...

# %%
df_cleaned["Model"].isna()
# Out:
# 0      False
# 1       True
# 2       True
# 5       True
# 7       True
#        ...
# 451    False
# 452    False
# 453    False
# 454    False
# 455    False
# Name: Model, Length: 447, dtype: bool

# %%
df_cleaned[df_cleaned["Model"].isna()]
# Out:
#                   coaster_name                  Length                 Speed  \
# 1     The Great Scenic Railway        967 m (3,173 ft)      60 km/h (37 mph)
# 2      Jack Rabbit (Kennywood)        2,132 ft (650 m)      45 mph (72 km/h)
# 5                 Giant Dipper        2,640 ft (800 m)      55 mph (89 km/h)
# 7    Thunderhawk (Dorney Park)        2,767 ft (843 m)      45 mph (72 km/h)
# 11    Wildcat (Lake Compounce)        2,746 ft (837 m)      48 mph (77 km/h)
# ..                         ...                     ...                   ...
# 435                Candymonium      4,636 ft (1,413 m)     76 mph (122 km/h)
# 436    F.L.Y. (roller coaster)  4,055.1 ft (1,236.0 m)  48.5 mph (78.1 km/h)
# 437              Objectif Mars    1,640.4 ft (500.0 m)  34.2 mph (55.0 km/h)
# 440    Sandy's Blasting Bronco    1,607.6 ft (490.0 m)  47.8 mph (76.9 km/h)
# 441             Texas Stingray      3,379 ft (1,030 m)      55 mph (89 km/h)
#
# ...

# %%
# lots of unknown model types in Model column. Instead of dropping them, I think for now I will make any null says "unknown"
df_cleaned.loc[:, "Model"] = df_cleaned["Model"].fillna("Unknown")

# %%
##Below code was an error. dropped Model column, attempting to drop "Model". Original mistake left in for clarity. Fix begins in line 46. 

#there is a lot of nulls in G-force column. This category is fine to leave out of overall analysis. Dropping the column
df_cleaned = df_cleaned.drop(["Model"], axis=1)

# %%
df_cleaned["Model"] = df["Model"]

# %%
df_cleaned.loc[:, "Model"] = df_cleaned["Model"].fillna("Unknown")

# %%
df_cleaned
# Out:
#                      coaster_name                Length                 Speed  \
# 0     Racer (1910 roller coaster)    4,500 ft (1,400 m)      40 mph (64 km/h)
# 1        The Great Scenic Railway      967 m (3,173 ft)      60 km/h (37 mph)
# 2         Jack Rabbit (Kennywood)      2,132 ft (650 m)      45 mph (72 km/h)
# 5                    Giant Dipper      2,640 ft (800 m)      55 mph (89 km/h)
# 7       Thunderhawk (Dorney Park)      2,767 ft (843 m)      45 mph (72 km/h)
# ..                            ...                   ...                   ...
# 451          Monster (Gröna Lund)  2,296.6 ft (700.0 m)  55.9 mph (90.0 km/h)
# 452  Storm Chaser (Paultons Park)                   NaN                   NaN
# 453  Stunt Pilot (roller coaster)      1,800 ft (550 m)      52 mph (84 km/h)
# 454         The Ride to Happiness  3,018.4 ft (920.0 m)  55.9 mph (90.0 km/h)
# 455                 VelociCoaster    4,700 ft (1,400 m)     70 mph (110 km/h)
#
# ...

# %%
#there is a lot of nulls in G-force column. This category is fine to leave out of overall analysis. Dropping the column

df_cleaned = df_cleaned.drop(["G-force"], axis=1)

# %%
df_cleaned
# Out:
#                      coaster_name                Length                 Speed  \
# 0     Racer (1910 roller coaster)    4,500 ft (1,400 m)      40 mph (64 km/h)
# 1        The Great Scenic Railway      967 m (3,173 ft)      60 km/h (37 mph)
# 2         Jack Rabbit (Kennywood)      2,132 ft (650 m)      45 mph (72 km/h)
# 5                    Giant Dipper      2,640 ft (800 m)      55 mph (89 km/h)
# 7       Thunderhawk (Dorney Park)      2,767 ft (843 m)      45 mph (72 km/h)
# ..                            ...                   ...                   ...
# 451          Monster (Gröna Lund)  2,296.6 ft (700.0 m)  55.9 mph (90.0 km/h)
# 452  Storm Chaser (Paultons Park)                   NaN                   NaN
# 453  Stunt Pilot (roller coaster)      1,800 ft (550 m)      52 mph (84 km/h)
# 454         The Ride to Happiness  3,018.4 ft (920.0 m)  55.9 mph (90.0 km/h)
# 455                 VelociCoaster    4,700 ft (1,400 m)     70 mph (110 km/h)
#
# ...

# %%
#track layout is not needed. Dropping
df_cleaned = df_cleaned.drop(["Track layout"], axis=1)

# %%
# designer might be necessary for analysis. Filling in NaN with "unknown" as to not lose rows
df_cleaned.loc[:, "Designer"] = df_cleaned["Designer"].fillna("Unknown")

# %%
#drop NaN in opening date
df_cleaned = df_cleaned.dropna(subset=["opening_date_clean"])

# %%
df_cleaned["opening_date_clean"].isna().sum()
# Out:
# np.int64(0)

# %%
df_cleaned
# Out:
#                      coaster_name                Length                 Speed  \
# 0     Racer (1910 roller coaster)    4,500 ft (1,400 m)      40 mph (64 km/h)
# 1        The Great Scenic Railway      967 m (3,173 ft)      60 km/h (37 mph)
# 2         Jack Rabbit (Kennywood)      2,132 ft (650 m)      45 mph (72 km/h)
# 5                    Giant Dipper      2,640 ft (800 m)      55 mph (89 km/h)
# 7       Thunderhawk (Dorney Park)      2,767 ft (843 m)      45 mph (72 km/h)
# ..                            ...                   ...                   ...
# 451          Monster (Gröna Lund)  2,296.6 ft (700.0 m)  55.9 mph (90.0 km/h)
# 452  Storm Chaser (Paultons Park)                   NaN                   NaN
# 453  Stunt Pilot (roller coaster)      1,800 ft (550 m)      52 mph (84 km/h)
# 454         The Ride to Happiness  3,018.4 ft (920.0 m)  55.9 mph (90.0 km/h)
# 455                 VelociCoaster    4,700 ft (1,400 m)     70 mph (110 km/h)
#
# ...

# %%
# investigate NaN in Height and Speed columns 
# get number of nulls first, then expand the rows
# May be able to manually enter correct stats

# %%
df_cleaned["Height"].isna().sum()
# Out:
# np.int64(22)

# %%
#expand on NaN in Height.
#conclusion : Missing Data at Random, no causation or correlation or clustering from other data points.
# 22 Rows of 446 is about %5, not enough to truly effect height analysis, there for dropping nulls is safe
height_is_null = df_cleaned[df_cleaned["Height"].isna()]
height_is_null
# Out:
#                                    coaster_name                  Length  \
# 19           Little Dipper (Conneaut Lake Park)                     NaN
# 21          Little Dipper (Memphis Kiddie Park)                     NaN
# 60                        Vortex (Calaway Park)                     NaN
# 66           Ultra Twister (Nagashima Spa Land)                     NaN
# 82           Ultra Twister (Nagashima Spa Land)                     NaN
# 93                Desert Storm (roller coaster)                     NaN
# 109                               Zach's Zoomer                     NaN
# 142                         Journey to Atlantis                     NaN
# 167                                    Montezum      1,030 m (3,380 ft)
# 171                            Rollie's Coaster                     NaN
# 179                           Diving Machine G5        1,250 ft (380 m)
# 195                                Insane Speed  2,677.17 ft (816.00 m)
# ...

# %%
#drop nulls in "Height" column
