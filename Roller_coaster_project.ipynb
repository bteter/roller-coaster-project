# %% [markdown]
# EDA for data analysis project using dataset full over roller coasters around the world. This workbook so far has just been exploring dataset, helping brainstorm project ideas.
#
# Dataset found at :https://www.kaggle.com/datasets/robikscube/rollercoaster-database/code

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 200)

# %%
df = pd.read_csv("/Users/benjaminteter/Desktop/Roller_Coaster_Project/coaster_db.csv")

# %%
df.head(25)
# Out:
#                               coaster_name              Length  \
# 0                       Switchback Railway      600 ft (180 m)
# 1                        Flip Flap Railway                 NaN
# 2   Switchback Railway (Euclid Beach Park)                 NaN
# 3             Loop the Loop (Coney Island)                 NaN
# 4             Loop the Loop (Young's Pier)                 NaN
# 5                           Cannon Coaster                 NaN
# 6                            Leap-The-Dips    1,452 ft (443 m)
# 7         Figure Eight (Euclid Beach Park)                 NaN
# 8                             Drop the Dip                 NaN
# 9       Scenic Railway (Euclid Beach Park)                 NaN
# 10          Loop the Loop (Olentangy Park)                 NaN
# 11                               Aero Dips                 NaN
# 12             Backety-Back Scenic Railway                 NaN
# 13             Racer (1910 roller coaster)  4,500 ft (1,400 m)
# ...

# %%
df.tail()
# Out:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1082            NaN                                 Steel
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
# investigating max speed as '240' seemed suspicious. Turns out its 240 kph. Formula Rossa in Abu Dhabi is fastest coaster in my data set.

top_speed = df[df["speed1_value"] == 240]
top_speed
# Out:
#       coaster_name              Length                 Speed  \
# 812  Formula Rossa  2,000 m (6,562 ft)  240 km/h (149.1 mph)
#
#                     Location     Status     Opening date              Type  \
# 812  Ferrari World Abu Dhabi  Operating  4 November 2010  Steel – Launched
#
#     Manufacturer                Height restriction                Model  \
# 812      Intamin  140–195 cm (4 ft 7 in–6 ft 5 in)  Accelerator Coaster
#
#               Height  Inversions      Lift/launch system Cost  \
# 812  52 m (170.6 ft)         0.0  Hydraulic Launch Track  NaN
#
#                                                 Trains Park section Duration  \
# 812  4 trains with 4 cars. Riders are arranged 2 ac...          NaN  1:32[1]
#
#                 Capacity G-force Designer Max vertical angle Drop  \
# 812  625 riders per hour  4.8[2]      NaN                NaN  NaN
#
#     Soft opening date Fast Lane available Replaced Track layout  \
# ...

# %% [markdown]
# note :
# - Speed1_value and speed2_value are coaster's speed as float, speed1_unit speed2_unit explain what unit of measurement that speed is measured in.
# - Same goes for height1 height2

# %%
# investigation min height, again as 4 seemed suspicious. 13 feet height for kiddie coaster, wikipedia listing confirmed this is correct.

min_height = df[df["height_value"] == 4]
min_height
# Out:
#        coaster_name         Length Speed         Location     Status  \
# 627  Dragon Express  80 m (260 ft)   NaN  Adventure World  Operating
#
#           Opening date            Type Manufacturer Height restriction  \
# 627  27 September 2003  Steel – Family     Zamperla                NaN
#
#                             Model       Height  Inversions Lift/launch system  \
# 627  Family Gravity Coaster 80STD  4 m (13 ft)         0.0                NaN
#
#     Cost                                             Trains Park section  \
# 627  NaN  Single train with 6 cars. Riders are arranged ...          NaN
#
#     Duration Capacity G-force Designer Max vertical angle Drop  \
# 627      NaN      NaN     NaN      NaN                NaN  NaN
#
#     Soft opening date Fast Lane available Replaced Track layout  \
# 627               NaN                 NaN      NaN          NaN
#
#     Fastrack available Soft opening date.1 Closing date Opened Replaced by  \
# ...

# %%
# operational coasters

operating_coasters = df[df["Status"] == "Operating"]
operating_coasters
# Out:
#                       coaster_name                Length  \
# 6                    Leap-The-Dips      1,452 ft (443 m)
# 13     Racer (1910 roller coaster)    4,500 ft (1,400 m)
# 15        The Great Scenic Railway      967 m (3,173 ft)
# 22         Jack Rabbit (Kennywood)      2,132 ft (650 m)
# 23         Jack Rabbit (Seabreeze)      2,130 ft (650 m)
# ...                            ...                   ...
# 1066          Monster (Gröna Lund)  2,296.6 ft (700.0 m)
# 1068  Storm Chaser (Paultons Park)                   NaN
# 1069  Stunt Pilot (roller coaster)      1,800 ft (550 m)
# 1070         The Ride to Happiness  3,018.4 ft (920.0 m)
# 1071                 VelociCoaster    4,700 ft (1,400 m)
#
#                      Speed                          Location     Status  \
# 6         10 mph (16 km/h)                     Lakemont Park  Operating
# 13        40 mph (64 km/h)                         Kennywood  Operating
# ...

# %%
#checking to find roller coasters at my home park, Six Flags St Louis

six_flags_stl = df[df["Location"].str.contains("Six Flags St. Louis", case=False, na=False)]
six_flags_stl
# Out:
#                           coaster_name              Length  \
# 101              River King Mine Train    2,500 ft (760 m)
# 120                     Rockin' Roller                 NaN
# 136                    Screamin' Eagle  3,872 ft (1,180 m)
# 518          The Boss (roller coaster)  4,631 ft (1,412 m)
# 750  American Thunder (roller coaster)    2,713 ft (827 m)
#
#                      Speed             Location     Status  \
# 101       37 mph (60 km/h)  Six Flags St. Louis  Operating
# 120                    NaN  Six Flags St. Louis    Removed
# 136      62 mph (100 km/h)  Six Flags St. Louis  Operating
# 518  66.3 mph (106.7 km/h)  Six Flags St. Louis  Operating
# 750       48 mph (77 km/h)  Six Flags St. Louis  Operating
#
#                      Opening date                Type  \
# 101                  June 5, 1971  Steel – Mine Train
# 120                          1975               Steel
# 136  April 10, 1976; 45 years ago                Wood
# ...

# %%
# Roller coasters at a Disney park!

# Checks rows that contain the word "Disney" in the Location column. Not case sensitive and not null.

# Checked Disney parks and St. Louis because I am most familiar with these locations. 
# My familiarity with their details allows me to better gauge the accuracy of the dataset.
# One issue I noticed is that rides with name changes (e.g., California Screamin' -> Incredicoaster) 
# are treated as two separate entries. Additionally, the old version is incorrectly listed as operational.


disney = df[df["Location"].str.contains("Disney", case=False, na=False)]
disney
# Out:
#                                 coaster_name                  Length  \
# 144              Space Mountain (Disneyland)      3,459 ft (1,054 m)
# 339      Indiana Jones et le Temple du Péril        600 m (2,000 ft)
# 382    Space Mountain: De la Terre à la Lune      3,281 ft (1,000 m)
# 564                     California Screamin'      6,072 ft (1,851 m)
# 574                       Goofy's Sky School        1,200 ft (370 m)
# 576                           Incredicoaster      6,072 ft (1,851 m)
# 580                       Mulholland Madness        1,200 ft (370 m)
# 606                           Primeval Whirl    1,377.9 ft (420.0 m)
# 689                           Raging Spirits        600 m (2,000 ft)
# 693                Space Mountain: Mission 2      3,281 ft (1,000 m)
# 700                       Expedition Everest  3,884.5 ft (1,184.0 m)
# 721                          Crush's Coaster                     NaN
# 861   Big Grizzly Mountain Runaway Mine Cars      1,100 m (3,600 ft)
# ...
