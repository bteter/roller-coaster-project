# %% [markdown]
# # New EDA workbook.
# The previous EDA was to brainstorm project ideas while I familiarized myself with the data set. This new EDA is more structured with a project in mind.
# <br>
# This project will focus on analyzing roller coaster manufacturers. I will examine the top manufacturers in the world by the number of rides they have built, identify which manufacturers have created the fastest and tallest roller coasters, and explore the different types of roller coaster each manufacturer specializes in

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 200)

# %%
df = pd.read_csv("/Users/benjaminteter/Desktop/Roller_Coaster_Project/coaster_db.csv")

# %%
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
# looking at the Manufacturer column

df['Manufacturer']
# Out:
# 0            LaMarcus Adna Thompson
# 1                      Lina Beecher
# 2                               NaN
# 3                    Edwin Prescott
# 4                    Edwin Prescott
#                    ...
# 1082              Anton Schwarzkopf
# 1083                        Intamin
# 1084                         Vekoma
# 1085      S&S – Sansei Technologies
# 1086    Rocky Mountain Construction
# Name: Manufacturer, Length: 1087, dtype: object

# %%
# List of manufacturers
# during data cleaning I will drop rows with no listed manufacturer
## Interesting discovery, some listed manufacturers are names of people, others are companies

manufacturers = df['Manufacturer'].dropna().tolist()
manufacturers
# Out:
# ['LaMarcus Adna Thompson',
#  'Lina Beecher',
#  'Edwin Prescott',
#  'Edwin Prescott',
#  'George Francis Meyer',
#  'Federal Construction Company',
#  'Arthur Jarvis',
#  'Lina Beecher',
#  'Charlie Mach',
#  'Fred W. Pearce',
#  'LaMarcus Thompson',
#  'The Gravity Group',
#  'Dinn Corporation',
#  'Philadelphia Toboggan Coasters',
#  'Harry C. Baker',
#  'Harry C. Baker',
#  'William Strickler',
#  'Philadelphia Toboggan Coasters',
#  'Prior and Church',
#  'Arthur Looff',
#  'Philadelphia Toboggan Coasters',
#  'Traver Engineering',
#  'Frank Prior, Fredrick Church',
#  'Traver Engineering',
#  'Traver Engineering',
#  'Traver Engineering',
#  'Traver Engineering',
#  'Traver Engineering',
#  'Traver Engineering',
#  'Traver Engineering',
#  'Charlie Mach',
#  'Philadelphia Toboggan Coasters',
#  'Traver Engineering',
#  'Frank W. Darling',
#  'Philadelphia Toboggan Coasters',
#  'Fred W. Pearce',
#  'Philadelphia Toboggan Coasters',
#  'National Amusement Devices',
# ...

# %%
# data set has 102 unique manufacturers.

df['Manufacturer'].nunique()
# Out:
# 102

# %%
df['Manufacturer'].isnull().sum()
# Out:
# np.int64(59)

# %%
#During data cleaning, remove these rows. Coaster manufacturer is unknown.
df[df['Manufacturer'].isnull()]
# Out:
#                                         coaster_name                  Length  \
# 2             Switchback Railway (Euclid Beach Park)                     NaN
# 7                   Figure Eight (Euclid Beach Park)                     NaN
# 9                 Scenic Railway (Euclid Beach Park)                     NaN
# 11                                         Aero Dips                     NaN
# 12                       Backety-Back Scenic Railway                     NaN
# 17                                    Racing Coaster                     NaN
# 18                                   Whirl Pool Dips                     NaN
# 19                     Green Dragon (Lake Compounce)                     NaN
# 24                   Scenic Railway (roller coaster)        3,000 ft (910 m)
# 25                           Roller Coaster (Lagoon)        762 m (2,500 ft)
# 30                           Pippin (roller coaster)        3,250 ft (990 m)
# ...

# %%
# number of roller coasters each manufacturer built.
manufacturer_counts = df['Manufacturer'].value_counts()
print(manufacturer_counts.head(25))
# Out:
# Manufacturer
# Vekoma                                                                                                         135
# Bolliger & Mabillard                                                                                           119
# Intamin                                                                                                         99
# Mack Rides                                                                                                      62
# Arrow Dynamics                                                                                                  54
# Anton Schwarzkopf                                                                                               49
# Gerstlauer                                                                                                      47
# Rocky Mountain Construction                                                                                     33
# ...

# %%
# roller coasters sorted fastest to slowest

top_speed = df.sort_values(by='speed_mph', ascending=False)
top_speed
# Out:
#                                 coaster_name                  Length  \
# 812                            Formula Rossa      2,000 m (6,562 ft)
# 685                                Kingda Ka        3,118 ft (950 m)
# 642                      Top Thrill Dragster        2,800 ft (850 m)
# 993               Red Force (roller coaster)        880 m (2,890 ft)
# 569                               Do-Dodonpa      1,244 m (4,081 ft)
# ...                                      ...                     ...
# 1063                      Lil' Devil Coaster       262.5 ft (80.0 m)
# 1064      Little Dipper (Conneaut Lake Park)                     NaN
# 1065             Looping Star (Clacton Pier)        365 m (1,198 ft)
# 1068            Storm Chaser (Paultons Park)                     NaN
# 1078  Guardians of the Galaxy: Cosmic Rewind  5,577.4 ft (1,700.0 m)
#
#                      Speed                   Location              Status  \
# ...

# %%
# coasters sorted by height descending. 
# There is an issue here I need to fix during data cleaning, I happen to know Kingda Ka is the tallest roller coaster in this data set, but is not listed first
# Its highted is listed in kilometers, not ft. 
# Need to write code that converts all height into ft. 

top_height = df.sort_values(by='height_ft', ascending=False)
top_height
# Out:
#                          coaster_name                Length  \
# 431                Tower of Terror II    376.4 m (1,235 ft)
# 993        Red Force (roller coaster)      880 m (2,890 ft)
# 553                 Steel Dragon 2000    2,479 m (8,133 ft)
# 870   Leviathan (Canada's Wonderland)    1,672 m (5,486 ft)
# 641                   Thunder Dolphin    1,066 m (3,497 ft)
# ...                               ...                   ...
# 1082          American Dreier Looping    3,444 ft (1,050 m)
# 1083        Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084        Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                          Tumbili        770 ft (230 m)
# 1086   Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                     Location  \
# 431    160.9 km/h (100.0 mph)                   Dreamworld
# 993        180 km/h (112 mph)                 Ferrari Land
# 553     152.9 km/h (95.0 mph)           Nagashima Spa Land
# ...
